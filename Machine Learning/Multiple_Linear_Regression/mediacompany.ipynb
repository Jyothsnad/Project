# %%
import pandas as pd

df = pd.read_csv('mediacompany.csv')
df.head()
# Out:
#        Date  Views_show  Visitors  Views_platform  Ad_impression  \
# 0  3/1/2017      183738   1260228         1706478     1060860448
# 1  3/2/2017      193763   1270561         1690727     1031846645
# 2  3/3/2017      210479   1248183         1726157     1010867575
# 3  3/4/2017      240061   1492913         1855353     1079194579
# 4  3/5/2017      446314   1594712         2041418     1357736987
#
#    Cricket_match_india  Character_A  Unnamed: 7
# 0                    0            0         NaN
# 1                    0            0         NaN
# 2                    0            0         NaN
# 3                    1            0         NaN
# 4                    0            0         NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Data columns (total 8 columns):
# Date                   80 non-null object
# Views_show             80 non-null int64
# Visitors               80 non-null int64
# Views_platform         80 non-null int64
# Ad_impression          80 non-null int64
# Cricket_match_india    80 non-null int64
# Character_A            80 non-null int64
# Unnamed: 7             0 non-null float64
# dtypes: float64(1), int64(6), object(1)
# memory usage: 5.1+ KB

# %%
df.isnull().sum()
# Out:
# Date                    0
# Views_show              0
# Visitors                0
# Views_platform          0
# Ad_impression           0
# Cricket_match_india     0
# Character_A             0
# Unnamed: 7             80
# dtype: int64

# %%
df = df.drop('Unnamed: 7',axis=1)
df.head()
# Out:
#        Date  Views_show  Visitors  Views_platform  Ad_impression  \
# 0  3/1/2017      183738   1260228         1706478     1060860448
# 1  3/2/2017      193763   1270561         1690727     1031846645
# 2  3/3/2017      210479   1248183         1726157     1010867575
# 3  3/4/2017      240061   1492913         1855353     1079194579
# 4  3/5/2017      446314   1594712         2041418     1357736987
#
#    Cricket_match_india  Character_A
# 0                    0            0
# 1                    0            0
# 2                    0            0
# 3                    1            0
# 4                    0            0

# %%
df.columns
# Out:
# Index(['Date', 'Views_show', 'Visitors', 'Views_platform', 'Ad_impression',
#        'Cricket_match_india', 'Character_A'],
#       dtype='object')

# %%
df['Date'] = pd.to_datetime(df['Date'])
df.head()
# Out:
#         Date  Views_show  Visitors  Views_platform  Ad_impression  \
# 0 2017-03-01      183738   1260228         1706478     1060860448
# 1 2017-03-02      193763   1270561         1690727     1031846645
# 2 2017-03-03      210479   1248183         1726157     1010867575
# 3 2017-03-04      240061   1492913         1855353     1079194579
# 4 2017-03-05      446314   1594712         2041418     1357736987
#
#    Cricket_match_india  Character_A
# 0                    0            0
# 1                    0            0
# 2                    0            0
# 3                    1            0
# 4                    0            0

# %%
for i in df.index.values: 
    df['Day'] = df.index.values+1
     
df.head()
# Out:
#         Date  Views_show  Visitors  Views_platform  Ad_impression  \
# 0 2017-03-01      183738   1260228         1706478     1060860448
# 1 2017-03-02      193763   1270561         1690727     1031846645
# 2 2017-03-03      210479   1248183         1726157     1010867575
# 3 2017-03-04      240061   1492913         1855353     1079194579
# 4 2017-03-05      446314   1594712         2041418     1357736987
#
#    Cricket_match_india  Character_A  Day
# 0                    0            0    1
# 1                    0            0    2
# 2                    0            0    3
# 3                    1            0    4
# 4                    0            0    5

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Data columns (total 8 columns):
# Date                   80 non-null datetime64[ns]
# Views_show             80 non-null int64
# Visitors               80 non-null int64
# Views_platform         80 non-null int64
# Ad_impression          80 non-null int64
# Cricket_match_india    80 non-null int64
# Character_A            80 non-null int64
# Day                    80 non-null int64
# dtypes: datetime64[ns](1), int64(7)
# memory usage: 5.1 KB

# %%
# Adding Weekday

df['weekday'] = (df['Day']+3)%7
df.weekday.replace(0,7,inplace=True)
df['weekday'] = df['weekday'].astype(int)
df.head()
# Out:
#         Date  Views_show  Visitors  Views_platform  Ad_impression  \
# 0 2017-03-01      183738   1260228         1706478     1060860448
# 1 2017-03-02      193763   1270561         1690727     1031846645
# 2 2017-03-03      210479   1248183         1726157     1010867575
# 3 2017-03-04      240061   1492913         1855353     1079194579
# 4 2017-03-05      446314   1594712         2041418     1357736987
#
#    Cricket_match_india  Character_A  Day  weekday
# 0                    0            0    1        4
# 1                    0            0    2        5
# 2                    0            0    3        6
# 3                    1            0    4        7
# 4                    0            0    5        1

# %% [markdown]
# Running 1st time

# %%
# Independent Variables
X = df[['Visitors','weekday']]

# Dependet Variable
y = df['Views_show']

from sklearn.linear_model import LinearRegression
# Representing LinearRegression as lr(Creating LinearRegression Object)
lr = LinearRegression()

# fit the model to the training data
lr.fit(X,y)

import statsmodels.api as sm
#Unlike SKLearn, statsmodels don't automatically fit a constant, 
#so you need to use the method sm.add_constant(X) in order to add a constant. 
X = sm.add_constant(X)
# create a fitted model in one line
lr_1 = sm.OLS(y,X).fit()

y_pred = lr_1.predict(X)
# Draw a plot of actual prices vs predicted prices by learned machine
import matplotlib.pyplot as plt

#plt.plot(df['lotsize'],df['price'],color='green')
plt.scatter(df['Visitors'],y,color='green')
plt.scatter(df['Visitors'],y_pred,color='red')

plt.xlabel('Visitors')
plt.ylabel('Views_Show')

# print the summary
print(lr_1.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Views_show   R-squared:                       0.485
# Model:                            OLS   Adj. R-squared:                  0.472
# Method:                 Least Squares   F-statistic:                     36.26
# Date:                Thu, 25 Apr 2019   Prob (F-statistic):           8.01e-12
# Time:                        21:50:51   Log-Likelihood:                -1042.5
# No. Observations:                  80   AIC:                             2091.
# Df Residuals:                      77   BIC:                             2098.
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -3.862e+04   1.07e+05     -0.360      0.720   -2.52e+05    1.75e+05
# Visitors       0.2787      0.057      4.911      0.000       0.166       0.392
# weekday    -3.591e+04   6591.205     -5.448      0.000    -4.9e+04   -2.28e+04
# ==============================================================================
# Omnibus:                        2.684   Durbin-Watson:                   0.650
# Prob(Omnibus):                  0.261   Jarque-Bera (JB):                2.653
# Skew:                           0.423   Prob(JB):                        0.265
# Kurtosis:                       2.718   Cond. No.                     1.46e+07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.46e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# Running 2nd time

# %%
# Independent Variables
X = df[['Visitors','weekday','Character_A']]

# Dependet Variable
y = df['Views_show']

from sklearn.linear_model import LinearRegression
# Representing LinearRegression as lr(Creating LinearRegression Object)
lr = LinearRegression()

# fit the model to the training data
lr.fit(X,y)

import statsmodels.api as sm
#Unlike SKLearn, statsmodels don't automatically fit a constant, 
#so you need to use the method sm.add_constant(X) in order to add a constant. 
X = sm.add_constant(X)
# create a fitted model in one line
lr_2 = sm.OLS(y,X).fit()

y_pred = lr_2.predict(X)
# Draw a plot of actual prices vs predicted prices by learned machine
import matplotlib.pyplot as plt

#plt.plot(df['lotsize'],df['price'],color='green')
plt.scatter(df['Visitors'],y,color='green')
plt.scatter(df['Visitors'],y_pred,color='red')

plt.xlabel('Visitors')
plt.ylabel('Views_Show')
# print the summary
print(lr_2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Views_show   R-squared:                       0.582
# Model:                            OLS   Adj. R-squared:                  0.565
# Method:                 Least Squares   F-statistic:                     35.25
# Date:                Thu, 25 Apr 2019   Prob (F-statistic):           2.21e-14
# Time:                        21:51:44   Log-Likelihood:                -1034.2
# No. Observations:                  80   AIC:                             2076.
# Df Residuals:                      76   BIC:                             2086.
# Df Model:                           3
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const        1.345e+04    9.8e+04      0.137      0.891   -1.82e+05    2.09e+05
# Visitors        0.2283      0.053      4.321      0.000       0.123       0.334
# weekday     -3.706e+04   5984.606     -6.192      0.000    -4.9e+04   -2.51e+04
# Character_A  1.016e+05   2.42e+04      4.195      0.000    5.34e+04     1.5e+05
# ==============================================================================
# Omnibus:                        4.318   Durbin-Watson:                   0.851
# Prob(Omnibus):                  0.115   Jarque-Bera (JB):                2.919
# Skew:                           0.298   Prob(JB):                        0.232
# Kurtosis:                       2.279   Cond. No.                     1.47e+07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.47e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# running 3rd time

# %%
# Independent Variables
X = df[['Visitors','weekday','Character_A','Cricket_match_india']]

# Dependet Variable
y = df['Views_show']

from sklearn.linear_model import LinearRegression
# Representing LinearRegression as lr(Creating LinearRegression Object)
lr = LinearRegression()

# fit the model to the training data
lr.fit(X,y)

import statsmodels.api as sm
#Unlike SKLearn, statsmodels don't automatically fit a constant, 
#so you need to use the method sm.add_constant(X) in order to add a constant. 
X = sm.add_constant(X)
# create a fitted model in one line
lr_3 = sm.OLS(y,X).fit()

y_pred = lr_3.predict(X)
# Draw a plot of actual prices vs predicted prices by learned machine
import matplotlib.pyplot as plt

#plt.plot(df['lotsize'],df['price'],color='green')
plt.scatter(df['Visitors'],y,color='green')
plt.scatter(df['Visitors'],y_pred,color='red')

plt.xlabel('Visitors')
plt.ylabel('Views_Show')
# print the summary
print(lr_3.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Views_show   R-squared:                       0.582
# Model:                            OLS   Adj. R-squared:                  0.560
# Method:                 Least Squares   F-statistic:                     26.16
# Date:                Thu, 25 Apr 2019   Prob (F-statistic):           1.36e-13
# Time:                        21:51:54   Log-Likelihood:                -1034.1
# No. Observations:                  80   AIC:                             2078.
# Df Residuals:                      75   BIC:                             2090.
# Df Model:                           4
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                7247.6907      1e+05      0.072      0.943   -1.93e+05    2.07e+05
# Visitors                0.2328      0.055      4.251      0.000       0.124       0.342
# weekday             -3.681e+04   6062.782     -6.072      0.000   -4.89e+04   -2.47e+04
# Character_A          9.893e+04   2.56e+04      3.863      0.000    4.79e+04     1.5e+05
# Cricket_match_india -1.389e+04   4.09e+04     -0.340      0.735   -9.54e+04    6.76e+04
# ==============================================================================
# Omnibus:                        4.184   Durbin-Watson:                   0.853
# Prob(Omnibus):                  0.123   Jarque-Bera (JB):                2.943
# Skew:                           0.311   Prob(JB):                        0.230
# Kurtosis:                       2.296   Cond. No.                     1.50e+07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.5e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# running 4th time

# %%
# Independent Variables
X = df[['Visitors','weekday','Character_A','Cricket_match_india','Ad_impression']]

# Dependet Variable
y = df['Views_show']

from sklearn.linear_model import LinearRegression
# Representing LinearRegression as lr(Creating LinearRegression Object)
lr = LinearRegression()

# fit the model to the training data
lr.fit(X,y)

import statsmodels.api as sm
#Unlike SKLearn, statsmodels don't automatically fit a constant, 
#so you need to use the method sm.add_constant(X) in order to add a constant. 
X = sm.add_constant(X)
# create a fitted model in one line
lr_4 = sm.OLS(y,X).fit()

y_pred = lr_4.predict(X)
# Draw a plot of actual prices vs predicted prices by learned machine
import matplotlib.pyplot as plt

#plt.plot(df['lotsize'],df['price'],color='green')
plt.scatter(df['Visitors'],y,color='green')
plt.scatter(df['Visitors'],y_pred,color='red')

plt.xlabel('Visitors')
plt.ylabel('Views_Show')
# print the summary
print(lr_4.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Views_show   R-squared:                       0.687
# Model:                            OLS   Adj. R-squared:                  0.666
# Method:                 Least Squares   F-statistic:                     32.45
# Date:                Thu, 25 Apr 2019   Prob (F-statistic):           2.30e-17
# Time:                        21:52:06   Log-Likelihood:                -1022.6
# No. Observations:                  80   AIC:                             2057.
# Df Residuals:                      74   BIC:                             2072.
# Df Model:                           5
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const               -3.267e+05    1.1e+05     -2.961      0.004   -5.47e+05   -1.07e+05
# Visitors                0.1355      0.052      2.625      0.011       0.033       0.238
# weekday             -1.585e+04   6767.076     -2.342      0.022   -2.93e+04   -2366.023
# Character_A         -1.297e+04   3.17e+04     -0.409      0.684   -7.62e+04    5.03e+04
# Cricket_match_india -6217.9376   3.57e+04     -0.174      0.862   -7.73e+04    6.49e+04
# Ad_impression           0.0003   6.37e-05      4.963      0.000       0.000       0.000
# ==============================================================================
# Omnibus:                        6.495   Durbin-Watson:                   0.753
# Prob(Omnibus):                  0.039   Jarque-Bera (JB):                5.443
# Skew:                           0.542   Prob(JB):                       0.0658
# Kurtosis:                       2.324   Cond. No.                     1.64e+10
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.64e+10. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# running 5th time

# %%
# Independent Variables
X = df[['Visitors','weekday','Character_A','Cricket_match_india','Ad_impression','Views_platform']]

# Dependet Variable
y = df['Views_show']

from sklearn.linear_model import LinearRegression
# Representing LinearRegression as lr(Creating LinearRegression Object)
lr = LinearRegression()

# fit the model to the training data
lr.fit(X,y)

import statsmodels.api as sm
#Unlike SKLearn, statsmodels don't automatically fit a constant, 
#so you need to use the method sm.add_constant(X) in order to add a constant. 
X = sm.add_constant(X)
# create a fitted model in one line
lr_5 = sm.OLS(y,X).fit()

y_pred = lr_5.predict(X)
# Draw a plot of actual prices vs predicted prices by learned machine
import matplotlib.pyplot as plt

#plt.plot(df['lotsize'],df['price'],color='green')
plt.scatter(df['Visitors'],y,color='green')
plt.scatter(df['Visitors'],y_pred,color='red')

plt.xlabel('Visitors')
plt.ylabel('Views_Show')
# print the summary
print(lr_5.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Views_show   R-squared:                       0.698
# Model:                            OLS   Adj. R-squared:                  0.674
# Method:                 Least Squares   F-statistic:                     28.18
# Date:                Thu, 25 Apr 2019   Prob (F-statistic):           3.59e-17
# Time:                        21:52:15   Log-Likelihood:                -1021.1
# No. Observations:                  80   AIC:                             2056.
# Df Residuals:                      73   BIC:                             2073.
# Df Model:                           6
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const               -3.993e+05   1.17e+05     -3.406      0.001   -6.33e+05   -1.66e+05
# Visitors               -0.1249      0.163     -0.766      0.446      -0.450       0.200
# weekday              -1.51e+04   6700.052     -2.254      0.027   -2.85e+04   -1745.743
# Character_A         -4.928e+04   3.81e+04     -1.294      0.200   -1.25e+05    2.66e+04
# Cricket_match_india   277.1144   3.55e+04      0.008      0.994   -7.04e+04     7.1e+04
# Ad_impression           0.0003    6.3e-05      5.095      0.000       0.000       0.000
# Views_platform          0.2332      0.139      1.681      0.097      -0.043       0.510
# ==============================================================================
# Omnibus:                       12.024   Durbin-Watson:                   0.695
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):                5.203
# Skew:                           0.381   Prob(JB):                       0.0742
# Kurtosis:                       2.010   Cond. No.                     1.78e+10
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.78e+10. This might indicate that there are
# strong multicollinearity or other numerical problems.
