# %%
import pandas as pd
train_data = pd.read_csv('D:\Public\Jyothsna\Python\Soc Softech\Project\Train1.txt',sep='\t')
train_data.head(3)
# Out:
#                            Description       Accession  ALL_19769_B-cell  \
# 0  AFFX-BioB-5_at (endogenous control)  AFFX-BioB-5_at              -214
# 1  AFFX-BioB-M_at (endogenous control)  AFFX-BioB-M_at              -153
# 2  AFFX-BioB-3_at (endogenous control)  AFFX-BioB-3_at               -58
#
#   Unnamed: 3  ALL_23953_B-cell Unnamed: 5  ALL_28373_B-cell Unnamed: 7  \
# 0          A              -135          A              -106          A
# 1          A              -114          A              -125          A
# 2          A               265          A               -76          A
#
#    ALL_9335_B-cell Unnamed: 9     ...      Unnamed: 69 AML_3  Unnamed: 71  \
# 0              -72          A     ...                A  -318            A
# 1             -144          A     ...                A  -192            A
# 2              238          A     ...                A   -95            A
#
#   AML_5  Unnamed: 73 AML_6  Unnamed: 75 AML_7  Unnamed: 77 Unnamed: 78
# ...

# %%
train_data = train_data.drop('Description',axis=1)
train_data.head(3)
# Out:
#         Accession  ALL_19769_B-cell Unnamed: 3  ALL_23953_B-cell Unnamed: 5  \
# 0  AFFX-BioB-5_at              -214          A              -135          A
# 1  AFFX-BioB-M_at              -153          A              -114          A
# 2  AFFX-BioB-3_at               -58          A               265          A
#
#    ALL_28373_B-cell Unnamed: 7  ALL_9335_B-cell Unnamed: 9  ALL_9692_B-cell  \
# 0              -106          A              -72          A             -413
# 1              -125          A             -144          A             -260
# 2               -76          A              238          A                7
#
#       ...      Unnamed: 69  AML_3 Unnamed: 71  AML_5 Unnamed: 73  AML_6  \
# 0     ...                A   -318           A    -32           A   -124
# 1     ...                A   -192           A    -49           A    -79
# 2     ...                A    -95           A     49           A    -37
#
#   Unnamed: 75  AML_7 Unnamed: 77  Unnamed: 78
# ...

# %%
train_data.columns
# Out:
# Index(['Accession', 'ALL_19769_B-cell', 'Unnamed: 3', 'ALL_23953_B-cell',
#        'Unnamed: 5', 'ALL_28373_B-cell', 'Unnamed: 7', 'ALL_9335_B-cell',
#        'Unnamed: 9', 'ALL_9692_B-cell', 'Unnamed: 11', 'ALL_14749_B-cell',
#        'Unnamed: 13', 'ALL_17281_B-cell', 'Unnamed: 15', 'ALL_19183_B-cell',
#        'Unnamed: 17', 'ALL_20414_B-cell', 'Unnamed: 19', 'ALL_21302_B-cell',
#        'Unnamed: 21', 'ALL_549_B-cell', 'Unnamed: 23', 'ALL_17929_B-cell',
#        'Unnamed: 25', 'ALL_20185_B-cell', 'Unnamed: 27', 'ALL_11103_B-cell',
#        'Unnamed: 29', 'ALL_18239_B-cell', 'Unnamed: 31', 'ALL_5982_B-cell',
#        'Unnamed: 33', 'ALL_7092_B-cell', 'Unnamed: 35', 'ALL_R11_B-cell',
#        'Unnamed: 37', 'ALL_R23_B-cell', 'Unnamed: 39', 'ALL_16415_T-cell',
#        'Unnamed: 41', 'ALL_19881_T-cell', 'Unnamed: 43', 'ALL_9186_T-cell',
#        'Unnamed: 45', 'ALL_9723_T-cell', 'Unnamed: 47', 'ALL_17269_T-cell',
# ...

# %%
train_data = train_data.drop(['Unnamed: 3','Unnamed: 5','Unnamed: 7','Unnamed: 9','Unnamed: 11',
             'Unnamed: 13','Unnamed: 15','Unnamed: 17','Unnamed: 19','Unnamed: 21',
             'Unnamed: 23','Unnamed: 25','Unnamed: 27','Unnamed: 29','Unnamed: 31',
             'Unnamed: 33','Unnamed: 35','Unnamed: 37','Unnamed: 39','Unnamed: 41',
             'Unnamed: 43','Unnamed: 45','Unnamed: 47','Unnamed: 49','Unnamed: 51',
             'Unnamed: 53','Unnamed: 55','Unnamed: 57','Unnamed: 59','Unnamed: 61',
             'Unnamed: 63', 'Unnamed: 65','Unnamed: 67','Unnamed: 69','Unnamed: 71',
             'Unnamed: 73','Unnamed: 75','Unnamed: 77','Unnamed: 78'],axis=1)
train_data.head()
# Out:
#         Accession  ALL_19769_B-cell  ALL_23953_B-cell  ALL_28373_B-cell  \
# 0  AFFX-BioB-5_at              -214              -135              -106
# 1  AFFX-BioB-M_at              -153              -114              -125
# 2  AFFX-BioB-3_at               -58               265               -76
# 3  AFFX-BioC-5_at                88                12               168
# 4  AFFX-BioC-3_at              -295              -419              -230
#
#    ALL_9335_B-cell  ALL_9692_B-cell  ALL_14749_B-cell  ALL_17281_B-cell  \
# 0              -72             -413               -67               -92
# 1             -144             -260               -93              -119
# 2              238                7                84               -31
# 3               55               -2                25               173
# 4             -399             -541              -179              -233
#
#    ALL_19183_B-cell  ALL_20414_B-cell  ...    AML_13  AML_14  AML_16  AML_20  \
# ...

# %%
train_data.columns
# Out:
# Index(['Accession', 'ALL_19769_B-cell', 'ALL_23953_B-cell', 'ALL_28373_B-cell',
#        'ALL_9335_B-cell', 'ALL_9692_B-cell', 'ALL_14749_B-cell',
#        'ALL_17281_B-cell', 'ALL_19183_B-cell', 'ALL_20414_B-cell',
#        'ALL_21302_B-cell', 'ALL_549_B-cell', 'ALL_17929_B-cell',
#        'ALL_20185_B-cell', 'ALL_11103_B-cell', 'ALL_18239_B-cell',
#        'ALL_5982_B-cell', 'ALL_7092_B-cell', 'ALL_R11_B-cell',
#        'ALL_R23_B-cell', 'ALL_16415_T-cell', 'ALL_19881_T-cell',
#        'ALL_9186_T-cell', 'ALL_9723_T-cell', 'ALL_17269_T-cell',
#        'ALL_14402_T-cell', 'ALL_17638_T-cell', 'ALL_22474_T-cell', 'AML_12',
#        'AML_13', 'AML_14', 'AML_16', 'AML_20', 'AML_1', 'AML_2', 'AML_3',
#        'AML_5', 'AML_6', 'AML_7'],
#       dtype='object')

# %%
train_data1 = pd.read_csv('D:\Public\Jyothsna\Python\Soc Softech\Project\Train1.txt',sep='\t',
                          usecols=['ALL_19769_B-cell', 'ALL_23953_B-cell', 'ALL_28373_B-cell',
       'ALL_9335_B-cell', 'ALL_9692_B-cell', 'ALL_14749_B-cell',
       'ALL_17281_B-cell', 'ALL_19183_B-cell', 'ALL_20414_B-cell',
       'ALL_21302_B-cell', 'ALL_549_B-cell', 'ALL_17929_B-cell',
       'ALL_20185_B-cell', 'ALL_11103_B-cell', 'ALL_18239_B-cell',
       'ALL_5982_B-cell', 'ALL_7092_B-cell', 'ALL_R11_B-cell',
       'ALL_R23_B-cell', 'ALL_16415_T-cell', 'ALL_19881_T-cell',
       'ALL_9186_T-cell', 'ALL_9723_T-cell', 'ALL_17269_T-cell',
       'ALL_14402_T-cell', 'ALL_17638_T-cell', 'ALL_22474_T-cell', 'AML_12',
       'AML_13', 'AML_14', 'AML_16', 'AML_20', 'AML_1', 'AML_2', 'AML_3',
       'AML_5', 'AML_6', 'AML_7'])
train_data1


train_data1[train_data1 < 20] = 20
train_data1.head()
# Out:
#    ALL_19769_B-cell  ALL_23953_B-cell  ALL_28373_B-cell  ALL_9335_B-cell  \
# 0                20                20                20               20
# 1                20                20                20               20
# 2                20               265                20              238
# 3                88                20               168               55
# 4                20                20                20               20
#
#    ALL_9692_B-cell  ALL_14749_B-cell  ALL_17281_B-cell  ALL_19183_B-cell  \
# 0               20                20                20                20
# 1               20                20                20                20
# 2               20                84                20                20
# 3               20                25               173               149
# 4               20                20                20                20
#
#    ALL_20414_B-cell  ALL_21302_B-cell  ...    AML_13  AML_14  AML_16  AML_20  \
# ...

# %%
#train_data1['mean'] = train_data1.mean()

#train_data1.head()
#train_data1.describe()
import math
math.log2(train_data1.values[0][0])
# Out:
# 4.321928094887363

# %%
#x = train_data[1:]
#for row in train_data:
#    if row[0:2] < 20:
#        train_data.replace(value=20,inplace=True)
#train_data.head(3)
#train_data.values[0:]
train_data1 = pd.read_csv('D:\Public\Jyothsna\Python\Soc Softech\Project\Train1.txt',sep='\t',
                          usecols=['ALL_19769_B-cell', 'ALL_23953_B-cell', 'ALL_28373_B-cell',
       'ALL_9335_B-cell', 'ALL_9692_B-cell', 'ALL_14749_B-cell',
       'ALL_17281_B-cell', 'ALL_19183_B-cell', 'ALL_20414_B-cell',
       'ALL_21302_B-cell', 'ALL_549_B-cell', 'ALL_17929_B-cell',
       'ALL_20185_B-cell', 'ALL_11103_B-cell', 'ALL_18239_B-cell',
       'ALL_5982_B-cell', 'ALL_7092_B-cell', 'ALL_R11_B-cell',
       'ALL_R23_B-cell', 'ALL_16415_T-cell', 'ALL_19881_T-cell',
       'ALL_9186_T-cell', 'ALL_9723_T-cell', 'ALL_17269_T-cell',
       'ALL_14402_T-cell', 'ALL_17638_T-cell', 'ALL_22474_T-cell', 'AML_12',
       'AML_13', 'AML_14', 'AML_16', 'AML_20', 'AML_1', 'AML_2', 'AML_3',
       'AML_5', 'AML_6', 'AML_7'])
train_data1
train_data1.values[0][0]

i = 0
j = 0
for row in train_data.values:
    if row[i][j] < '20':
        row[i][j] = '20'
        train_data1.replace(value=20,inplace=True)
        j+=1
train_data1
# Out:
#       ALL_19769_B-cell  ALL_23953_B-cell  ALL_28373_B-cell  ALL_9335_B-cell  \
# 0                 -214              -135              -106              -72
# 1                 -153              -114              -125             -144
# 2                  -58               265               -76              238
# 3                   88                12               168               55
# 4                 -295              -419              -230             -399
# 5                 -558              -585              -284             -551
# 6                  199               158                 4              131
# 7                 -176              -253              -122             -179
# 8                  252                49                70              126
# 9                  206                31               252              -20
# 10                 -41               363               155             -115
# ...

# %%
import math 
math.

# %%
# VIF

import numpy as np
from statsmodels.stats.outliers_influence import variance_inflation_factor 

independent_variables = ['ALL_19769_B-cell', 'ALL_23953_B-cell', 'ALL_28373_B-cell',
       'ALL_9335_B-cell', 'ALL_9692_B-cell', 'ALL_14749_B-cell',
       'ALL_17281_B-cell', 'ALL_19183_B-cell', 'ALL_20414_B-cell',
       'ALL_21302_B-cell', 'ALL_549_B-cell', 'ALL_17929_B-cell',
       'ALL_20185_B-cell', 'ALL_11103_B-cell', 'ALL_18239_B-cell',
       'ALL_5982_B-cell', 'ALL_7092_B-cell', 'ALL_R11_B-cell',
       'ALL_R23_B-cell', 'ALL_16415_T-cell', 'ALL_19881_T-cell',
       'ALL_9186_T-cell', 'ALL_9723_T-cell', 'ALL_17269_T-cell',
       'ALL_14402_T-cell', 'ALL_17638_T-cell', 'ALL_22474_T-cell', 'AML_12',
       'AML_13', 'AML_14', 'AML_16', 'AML_20', 'AML_1', 'AML_2', 'AML_3',
       'AML_5', 'AML_6', 'AML_7']

X = train_data[independent_variables]  # independent variables
y = train_data['Accession'] # dependent variable

thresh = 20

for i in np.arange(0,len(independent_variables)):
    vif = [variance_inflation_factor(X[independent_variables].values,ix)
          for ix in range(X[independent_variables].shape[1])]
    maxloc = vif.index(max(vif))  # store the index of max vif 
    if max(vif) > thresh:   # comparing the max vif with our thresh
        print('VIF : ',vif)
        print('dropping : ',X[independent_variables].columns[maxloc],
              'at index : ',maxloc)
        del independent_variables[maxloc]
    else:
        break
        
print('Final Independent Variables : ',independent_variables)
# Out:
# VIF :  [28.544470950155812, 40.90659709618627, 38.36888976772954, 18.902321631900616, 17.72982344075513, 27.506383991748294, 25.70061692959386, 37.53404643610785, 37.88593656351901, 12.864625622881, 14.795282683186457, 27.193692311959232, 11.986776234577379, 6.211281055863588, 18.063026844154148, 43.8296779261425, 22.43562892563547, 26.01529497772287, 22.465680886690237, 22.686934366113015, 24.15134369744577, 33.54126718588049, 22.82244748267075, 27.9780505855145, 28.065109014028575, 20.761860913214417, 29.201618564980063, 23.4520174685621, 16.608653538476304, 15.633090052652113, 18.783653387375825, 15.47039822107084, 27.556529115183597, 17.423092629473615, 16.694669008452593, 22.193148679020176, 23.235933183280437, 18.704901974198748]
# dropping :  ALL_5982_B-cell at index :  15
# ...

# %%
train_data1 = pd.read_csv('D:\Public\Jyothsna\Python\Soc Softech\Project\Train1.txt',sep='\t',
                          usecols=['Accession','ALL_9335_B-cell', 'ALL_9692_B-cell','ALL_17281_B-cell', 
                         'ALL_21302_B-cell', 'ALL_549_B-cell', 'ALL_20185_B-cell',
                         'ALL_11103_B-cell', 'ALL_18239_B-cell', 'ALL_7092_B-cell',
                         'ALL_R23_B-cell', 'ALL_19881_T-cell', 'ALL_9723_T-cell',
                         'ALL_17638_T-cell', 'ALL_22474_T-cell', 'AML_12', 'AML_13',
                         'AML_14', 'AML_16', 'AML_20', 'AML_2', 'AML_3', 'AML_5', 'AML_6', 'AML_7'])
train_data1
train_data1.to_csv('traindata.txt',sep='\t', encoding='utf-8')

# %%
# Evaluate Our Model
# OLS

independent_variables = ['ALL_9335_B-cell', 'ALL_9692_B-cell', 'ALL_17281_B-cell', 
                         'ALL_21302_B-cell', 'ALL_549_B-cell', 'ALL_20185_B-cell',
                         'ALL_11103_B-cell', 'ALL_18239_B-cell', 'ALL_7092_B-cell',
                         'ALL_R23_B-cell', 'ALL_19881_T-cell', 'ALL_9723_T-cell',
                         'ALL_17638_T-cell', 'ALL_22474_T-cell', 'AML_12', 'AML_13',
                         'AML_14', 'AML_16', 'AML_20', 'AML_2', 'AML_3', 'AML_5', 'AML_6', 'AML_7']

from sklearn.model_selection import train_test_split

X = df[independent_variables]
y = df['Accession']

X_train, X_test, y_train, y_test = train_test_split(X,y,train_size=.80,random_state=1)

print('X_train',X_train.shape)
print('X_test',X_test.shape)
print('y_train',y_train.shape)
print('y_test',y_test.shape)
# Out:
# X_train (5703, 24)
# X_test (1426, 24)
# y_train (5703,)
# y_test (1426,)

# %%
import statsmodels.api as sm
import scipy.stats as stats

#lm = sm.OLS(y_train,X_train).fit()
#print(lm.summary())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-70-33fa1869e2ec> in <module>()
#       5 #print(lm.summary())
#       6
# ----> 7 stats.describe()
#
# TypeError: describe() missing 1 required positional argument: 'a'
