# %%
# Load Our Dataset
import pandas as pd
df = pd.read_csv('D:\Public\Jyothsna\Python\Soc Softech\Project\data_set_ALL_AML_train.tsv',sep='\t')
df.head(3)
# Out:
#                                     Gene Description  Gene Accession Number  \
# AFFX-BioB-5_at (endogenous control)   AFFX-BioB-5_at                   -214
# AFFX-BioB-M_at (endogenous control)   AFFX-BioB-M_at                   -153
# AFFX-BioB-3_at (endogenous control)   AFFX-BioB-3_at                    -58
#
#                                      1  call  2  call.1  3  call.2  4  call.3  \
# AFFX-BioB-5_at (endogenous control)  A  -139  A     -76  A    -135  A    -106
# AFFX-BioB-M_at (endogenous control)  A   -73  A     -49  A    -114  A    -125
# AFFX-BioB-3_at (endogenous control)  A    -1  A    -307  A     265  A     -76
#
#                                       ...    29  call.33 30  call.34 31  \
# AFFX-BioB-5_at (endogenous control)   ...     A     -318  A      -32  A
# AFFX-BioB-M_at (endogenous control)   ...     A     -192  A      -49  A
# AFFX-BioB-3_at (endogenous control)   ...     A      -95  A       49  A
#
# ...

# %%
df = df.drop('Gene Description',axis=1)
df.head(3)
# Out:
#                                      Gene Accession Number  1  call  2  \
# AFFX-BioB-5_at (endogenous control)                   -214  A  -139  A
# AFFX-BioB-M_at (endogenous control)                   -153  A   -73  A
# AFFX-BioB-3_at (endogenous control)                    -58  A    -1  A
#
#                                      call.1  3  call.2  4  call.3  5   ...    \
# AFFX-BioB-5_at (endogenous control)     -76  A    -135  A    -106  A   ...
# AFFX-BioB-M_at (endogenous control)     -49  A    -114  A    -125  A   ...
# AFFX-BioB-3_at (endogenous control)    -307  A     265  A     -76  A   ...
#
#                                      29 call.33  30 call.34  31 call.35  32  \
# AFFX-BioB-5_at (endogenous control)   A    -318   A     -32   A    -124   A
# AFFX-BioB-M_at (endogenous control)   A    -192   A     -49   A     -79   A
# AFFX-BioB-3_at (endogenous control)   A     -95   A      49   A     -37   A
#
#                                     call.36  33 call.37
# ...

# %%
df.columns
# Out:
# Index(['Gene Description', 'Gene Accession Number', '1', 'call', '2', 'call.1',
#        '3', 'call.2', '4', 'call.3', '5', 'call.4', '6', 'call.5', '7',
#        'call.6', '8', 'call.7', '9', 'call.8', '10', 'call.9', '11', 'call.10',
#        '12', 'call.11', '13', 'call.12', '14', 'call.13', '15', 'call.14',
#        '16', 'call.15', '17', 'call.16', '18', 'call.17', '19', 'call.18',
#        '20', 'call.19', '21', 'call.20', '22', 'call.21', '23', 'call.22',
#        '24', 'call.23', '25', 'call.24', '26', 'call.25', '27', 'call.26',
#        '34', 'call.27', '35', 'call.28', '36', 'call.29', '37', 'call.30',
#        '38', 'call.31', '28', 'call.32', '29', 'call.33', '30', 'call.34',
#        '31', 'call.35', '32', 'call.36', '33', 'call.37'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Gene Description            0
# Gene Accession Number       0
# 1                           0
# call                        0
# 2                           0
# call.1                      0
# 3                           0
# call.2                      0
# 4                           0
# call.3                      0
# 5                           0
# call.4                      0
# 6                           0
# call.5                      0
# 7                           0
# call.6                      0
# 8                           0
# call.7                      0
# 9                           0
# call.8                      0
# 10                          0
# call.9                      0
# 11                          0
# call.10                     0
# 12                          0
# call.11                     0
# 13                          0
# call.12                     0
# 14                          0
# call.13                     0
#                          ...
# ...

# %%
df = df.drop('call.37',axis=1)
df.head(3)
# Out:
#                                     Gene Description  Gene Accession Number  \
# AFFX-BioB-5_at (endogenous control)   AFFX-BioB-5_at                   -214
# AFFX-BioB-M_at (endogenous control)   AFFX-BioB-M_at                   -153
# AFFX-BioB-3_at (endogenous control)   AFFX-BioB-3_at                    -58
#
#                                      1  call  2  call.1  3  call.2  4  call.3  \
# AFFX-BioB-5_at (endogenous control)  A  -139  A     -76  A    -135  A    -106
# AFFX-BioB-M_at (endogenous control)  A   -73  A     -49  A    -114  A    -125
# AFFX-BioB-3_at (endogenous control)  A    -1  A    -307  A     265  A     -76
#
#                                     ... call.32  29 call.33  30 call.34  31  \
# AFFX-BioB-5_at (endogenous control) ...      15   A    -318   A     -32   A
# AFFX-BioB-M_at (endogenous control) ...    -114   A    -192   A     -49   A
# AFFX-BioB-3_at (endogenous control) ...       2   A     -95   A      49   A
#
# ...

# %%
df_1 = pd.get_dummies(df['1'],prefix='1')
df = pd.concat([df , df_1] , axis=1)
del df['1']

df_2 = pd.get_dummies(df['2'],prefix='2')
df = pd.concat([df , df_2] , axis=1)
del df['2']

df_3 = pd.get_dummies(df['3'],prefix='3')
df = pd.concat([df , df_3] , axis=1)
del df['3']

df_4 = pd.get_dummies(df['4'],prefix='4')
df = pd.concat([df , df_4] , axis=1)
del df['4']

df_5 = pd.get_dummies(df['5'],prefix='5')
df = pd.concat([df , df_5] , axis=1)
del df['5']

df_6 = pd.get_dummies(df['6'],prefix='6')
df = pd.concat([df , df_6] , axis=1)
del df['6']

df_7 = pd.get_dummies(df['7'],prefix='7')
df = pd.concat([df , df_7] , axis=1)
del df['7']

df_8 = pd.get_dummies(df['8'],prefix='8')
df = pd.concat([df , df_8] , axis=1)
del df['8']
                
df_9 = pd.get_dummies(df['9'],prefix='9')
df = pd.concat([df , df_9] , axis=1)
del df['9']

df_10 = pd.get_dummies(df['10'],prefix='10')
df = pd.concat([df , df_10] , axis=1)
del df['10']

df_11 = pd.get_dummies(df['11'],prefix='11')
df = pd.concat([df , df_11] , axis=1)
del df['11']

df_12 = pd.get_dummies(df['12'],prefix='12')
df = pd.concat([df , df_12] , axis=1)
del df['12']                                
                
df_13 = pd.get_dummies(df['13'],prefix='13')
df = pd.concat([df , df_13] , axis=1)
del df['13']
                
df_14 = pd.get_dummies(df['14'],prefix='14')
df = pd.concat([df , df_14] , axis=1)
del df['14']                
                
df_15 = pd.get_dummies(df['15'],prefix='15')
df = pd.concat([df , df_15] , axis=1)
del df['15']                
                
df_16 = pd.get_dummies(df['16'],prefix='16')
df = pd.concat([df , df_16] , axis=1)
del df['16']                
                
df_17 = pd.get_dummies(df['17'],prefix='17')
df = pd.concat([df , df_17] , axis=1)
del df['17']                
                
df_18 = pd.get_dummies(df['18'],prefix='18')
df = pd.concat([df , df_18] , axis=1)
del df['18']                
                
df_19 = pd.get_dummies(df['19'],prefix='19')
df = pd.concat([df , df_19] , axis=1)
del df['19']                
                
df_20 = pd.get_dummies(df['20'],prefix='20')
df = pd.concat([df , df_20] , axis=1)
del df['20']                
                
df_21 = pd.get_dummies(df['21'],prefix='21')
df = pd.concat([df , df_21] , axis=1)
del df['21']                
                
df_22 = pd.get_dummies(df['22'],prefix='22')
df = pd.concat([df , df_22] , axis=1)
del df['22']                
                
df_23 = pd.get_dummies(df['23'],prefix='23')
df = pd.concat([df , df_23] , axis=1)
del df['23']                
                
df_24 = pd.get_dummies(df['24'],prefix='24')
df = pd.concat([df , df_24] , axis=1)
del df['24']                
                
df_25 = pd.get_dummies(df['25'],prefix='25')
df = pd.concat([df , df_25] , axis=1)
del df['25']                
                
df_26 = pd.get_dummies(df['26'],prefix='26')
df = pd.concat([df , df_26] , axis=1)
del df['26']                
                
df_27 = pd.get_dummies(df['27'],prefix='27')
df = pd.concat([df , df_27] , axis=1)
del df['27']                
                
df_28 = pd.get_dummies(df['28'],prefix='28')
df = pd.concat([df , df_28] , axis=1)
del df['28']                
                
df_29 = pd.get_dummies(df['29'],prefix='29')
df = pd.concat([df , df_29] , axis=1)
del df['29']                
                
df_30 = pd.get_dummies(df['30'],prefix='30')
df = pd.concat([df , df_30] , axis=1)
del df['30']                
                
df_31 = pd.get_dummies(df['31'],prefix='31')
df = pd.concat([df , df_31] , axis=1)
del df['31']                
                
df_32 = pd.get_dummies(df['32'],prefix='32')
df = pd.concat([df , df_32] , axis=1)
del df['32']                
                
df_33 = pd.get_dummies(df['33'],prefix='33')
df = pd.concat([df , df_33] , axis=1)
del df['33']

df.head(3)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\Public\Jyothsna\Python\Anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '1'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-51-a5dfe72c5004> in <module>()
# ...
